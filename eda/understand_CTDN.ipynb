# %%
from frameworks.LightenDiffusion.models import CTDN
from dataset_registery.registery import DatasetRegistry
from torchsummary import summary
from eda.helpers.training_helpers import train_model, get_optimizer
from eda.helpers.losses import ctdn_loss_wrapper
import torch
# %load_ext autoreload
# %autoreload 2

# %%
data_name = "NTIRE2025"
dataset_id = "okhater/NTIRE_LLE_2025"
source = "huggingface"

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device used : {device}")
# Out:
# Device used : cpu

# %%
registry = DatasetRegistry()
registry.register_dataset(
    name=data_name,
    dataset_id=dataset_id,
    splits=["train", "validation", "test"],
    dataset_type="paired"
)


train_loader = registry.get_dataloader(data_name, "train", batch_size=32, shuffle=True)
val_loader = registry.get_dataloader(data_name, "validation", batch_size=32, shuffle=True)
test_loader = registry.get_dataloader(data_name, "test", batch_size=32, shuffle=True)

# %%
model = CTDN()
model = model.to(device)

# %%
summary(model, (3, 256, 256), device="cpu", batch_size=1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [1, 64, 256, 256]           4,864
#             Conv2d-2          [1, 64, 256, 256]         102,464
#             Conv2d-3          [1, 64, 256, 256]          36,928
#          LeakyReLU-4          [1, 64, 256, 256]               0
#             Conv2d-5          [1, 64, 256, 256]          36,928
#             Conv2d-6          [1, 64, 256, 256]           4,160
#          Res_block-7          [1, 64, 256, 256]               0
#             Conv2d-8          [1, 64, 128, 128]          36,928
#             Conv2d-9         [1, 128, 128, 128]          73,856
#         LeakyReLU-10         [1, 128, 128, 128]               0
#            Conv2d-11         [1, 128, 128, 128]         147,584
#            Conv2d-12         [1, 128, 128, 128]           8,320
#         Res_block-13         [1, 128, 128, 128]               0
#            Conv2d-14           [1, 128, 64, 64]         147,584
#            Conv2d-15           [1, 256, 64, 64]         295,168
#         LeakyReLU-16           [1, 256, 64, 64]               0
#            Conv2d-17           [1, 256, 64, 64]         590,080
#            Conv2d-18           [1, 256, 64, 64]          33,024
#         Res_block-19           [1, 256, 64, 64]               0
#            Conv2d-20           [1, 256, 32, 32]         590,080
#   feature_pyramid-21  [[-1, 64, 128, 128], [-1, 128, 64, 64], [-1, 256, 32, 32]]               0
#            Conv2d-22           [1, 128, 32, 32]         295,040
#         LeakyReLU-23           [1, 128, 32, 32]               0
#            Conv2d-24            [1, 64, 32, 32]          73,792
#         LeakyReLU-25            [1, 64, 32, 32]               0
#            Conv2d-26             [1, 3, 32, 32]           1,731
#      channel_down-27             [1, 3, 32, 32]               0
#          ReconNet-28  [[-1, 3, 32, 32], [-1, 3, 32, 32]]               0
#            Conv2d-29            [1, 64, 32, 32]           1,792
#            Conv2d-30            [1, 64, 32, 32]          36,928
#         LeakyReLU-31            [1, 64, 32, 32]               0
#            Conv2d-32            [1, 64, 32, 32]          36,928
#            Conv2d-33            [1, 64, 32, 32]           4,160
#         Res_block-34            [1, 64, 32, 32]               0
#            Conv2d-35            [1, 64, 32, 32]          36,928
#         LeakyReLU-36            [1, 64, 32, 32]               0
#            Conv2d-37            [1, 64, 32, 32]          36,928
#            Conv2d-38            [1, 64, 32, 32]           4,160
#         Res_block-39            [1, 64, 32, 32]               0
#            Conv2d-40            [1, 64, 32, 32]             640
#            Conv2d-41            [1, 64, 32, 32]          36,928
#         LeakyReLU-42            [1, 64, 32, 32]               0
#            Conv2d-43            [1, 64, 32, 32]          36,928
#            Conv2d-44            [1, 64, 32, 32]           4,160
#         Res_block-45            [1, 64, 32, 32]               0
#            Conv2d-46            [1, 64, 32, 32]          36,928
#         LeakyReLU-47            [1, 64, 32, 32]               0
#            Conv2d-48            [1, 64, 32, 32]          36,928
#            Conv2d-49            [1, 64, 32, 32]           4,160
#         Res_block-50            [1, 64, 32, 32]               0
#            Conv2d-51            [1, 64, 32, 32]             640
#            Conv2d-52            [1, 64, 32, 32]           4,160
#        Depth_conv-53            [1, 64, 32, 32]               0
#            Conv2d-54            [1, 64, 32, 32]             640
#            Conv2d-55            [1, 64, 32, 32]           4,160
#        Depth_conv-56            [1, 64, 32, 32]               0
#            Conv2d-57            [1, 64, 32, 32]             640
#            Conv2d-58            [1, 64, 32, 32]           4,160
#        Depth_conv-59            [1, 64, 32, 32]               0
#           Dropout-60            [1, 32, 64, 64]               0
#   Cross_Attention-61            [1, 64, 32, 32]               0
#            Conv2d-62           [1, 192, 32, 32]          12,480
#            Conv2d-63           [1, 192, 32, 32]           1,920
#            Conv2d-64            [1, 64, 32, 32]           4,160
#    Self_Attention-65            [1, 64, 32, 32]               0
#            Conv2d-66            [1, 64, 32, 32]          36,928
#         LeakyReLU-67            [1, 64, 32, 32]               0
#            Conv2d-68            [1, 64, 32, 32]          36,928
#            Conv2d-69            [1, 64, 32, 32]           4,160
#         Res_block-70            [1, 64, 32, 32]               0
#            Conv2d-71             [1, 3, 32, 32]           1,731
#            Conv2d-72            [1, 64, 32, 32]          36,928
#         LeakyReLU-73            [1, 64, 32, 32]               0
#            Conv2d-74            [1, 64, 32, 32]          36,928
#            Conv2d-75            [1, 64, 32, 32]           4,160
#         Res_block-76            [1, 64, 32, 32]               0
#            Conv2d-77             [1, 1, 32, 32]             577
#     Retinex_decom-78  [[-1, 3, 32, 32], [-1, 3, 32, 32]]               0
# ================================================================
# Total params: 2,984,327
# Trainable params: 2,984,327
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 531.08
# Params size (MB): 11.38
# Estimated Total Size (MB): 543.21
# ----------------------------------------------------------------

# %%
optimizer=get_optimizer(model)

# %%
model, losses = train_model(
        model,
        data_loaders=(train_loader, val_loader),
        criterion=ctdn_loss_wrapper, 
        optimizer=optimizer, 
        num_epochs = 5, 
        batch_size= 32, 
        device=device, 
        val_frequency = 2,
        patience = 3
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 model, losses = train_model(
#       2         model,
#       3         data_loaders=(train_loader, val_loader),
# ----> 4         criterion=ctdn_loss,
#       5         optimizer=optimizer,
#       6         num_epochs = 5,
#       7         batch_size= 32,
#       8         device=device,
#       9         val_frequency = 2,
#      10         patience = 3
#      11         )
#
# NameError: name 'ctdn_loss' is not defined
